# %%
#%pip install kallisto multiqc pandas seaborn matplotlib

import os
import pysradb
import subprocess

# %%
# Set the working directory for the data
data_dir = "rna_seq_data"
os.makedirs(data_dir, exist_ok=True)

# SRA IDs for the samples
sra_ids = ["SRR5458657", "SRR5458658", "SRR5458661", "SRR5458662"]

# %%
# Download the RNAseq data using pysradb
# for sra_id in sra_ids:
#     command = f"pysradb download -p {sra_id} --out-dir {data_dir}"
#     subprocess.run(command, shell=True)

# %%
# Example URL for the human transcriptome from Ensembl
transcriptome_url = "ftp://ftp.ensembl.org/pub/release-106/fasta/homo_sapiens/cdna/Homo_sapiens.GRCh38.cdna.all.fa.gz"
transcriptome_file = os.path.join("Homo_sapiens.GRCh38.cdna.all.fa.gz")

if not os.path.exists(transcriptome_file):
    subprocess.run(f"wget -O {transcriptome_file} {transcriptome_url}", shell=True)


# # Create directories for Kallisto output
# kallisto_output_dir = os.path.join(data_dir, "kallisto_output")
# os.makedirs(kallisto_output_dir, exist_ok=True)
# Out:
# --2024-06-29 09:01:05--  ftp://ftp.ensembl.org/pub/release-106/fasta/homo_sapiens/cdna/Homo_sapiens.GRCh38.cdna.all.fa.gz
#            => ‘Homo_sapiens.GRCh38.cdna.all.fa.gz’
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.169
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.169|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/release-106/fasta/homo_sapiens/cdna ... done.
# ==> SIZE Homo_sapiens.GRCh38.cdna.all.fa.gz ... 76937571
# ==> PASV ... done.    ==> RETR Homo_sapiens.GRCh38.cdna.all.fa.gz ... done.
# Length: 76937571 (73M) (unauthoritative)
#
#      0K .......... .......... .......... .......... ..........  0% 3.61M 20s
#     50K .......... .......... .......... .......... ..........  0% 18.8M 12s
#    100K .......... .......... .......... .......... ..........  0% 26.1M 9s
#    150K .......... .......... .......... .......... ..........  0% 19.4M 8s
# ...

# %% [markdown]
# https://pachterlab.github.io/kallisto/manual
#
# follow instruction buidling index with reference ensembl Human cDNA
